# %% [markdown]
# # Import all necessary Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Import all cleaned CSVs

# %%
base_path = "C:/Users/mitan/Downloads/"

drivers = pd.read_csv(base_path + "drivers_cleaned.csv")
constructors = pd.read_csv(base_path + "constructors_cleaned.csv")
circuits = pd.read_csv(base_path + "circuits_cleaned.csv")
races = pd.read_csv(base_path + "races_cleaned.csv")
results = pd.read_csv(base_path + "results_cleaned.csv")
lap_times = pd.read_csv(base_path + "lap_times_cleaned.csv")
pit_stops = pd.read_csv(base_path + "pit_stops_cleaned.csv")
qualifying = pd.read_csv(base_path + "qualifying_cleaned.csv")
status = pd.read_csv(base_path + "status_cleaned.csv")

print("All datasets loaded")
# Out:
# All datasets loaded

# %%
datasets = {
    "drivers": drivers,
    "constructors": constructors,
    "circuits": circuits,
    "races": races,
    "results": results,
    "lap_times":lap_times,
    "pit_stops":pit_stops,
    "qualifying":qualifying,
    "status":status
}

for name, df in datasets.items():
    print(name, ":")
    print(df.shape)
    df.info()
    print(df.describe())
# Out:
# drivers :
# (861, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 861 entries, 0 to 860
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   driverId     861 non-null    int64
#  1   driverRef    861 non-null    object
#  2   number       861 non-null    object
#  3   code         861 non-null    object
#  4   forename     861 non-null    object
#  5   surname      861 non-null    object
#  6   dob          854 non-null    object
#  7   nationality  861 non-null    object
#  8   name         861 non-null    object
#  9   age          854 non-null    float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 67.4+ KB
#          driverId         age
# count  861.000000  854.000000
# mean   431.061556   84.392272
# std    248.793797   23.801090
# min      1.000000   21.000000
# 25%    216.000000   68.250000
# 50%    431.000000   89.000000
# 75%    646.000000  103.000000
# ...

# %% [markdown]
# # Visualisation and Insights

# %%
sns.set_theme(style="whitegrid", palette='pastel')
